# %% [markdown]
# ## PyTorch/TPU MNIST Demo
#
# This colab example corresponds to the implementation under [test_train_mp_mnist.py](https://github.com/pytorch/xla/blob/master/test/test_train_mp_mnist.py).

# %% [markdown]
# <h3>  &nbsp;&nbsp;Use Colab Cloud TPU&nbsp;&nbsp; <a href="https://cloud.google.com/tpu/"><img valign="middle" src="https://raw.githubusercontent.com/GoogleCloudPlatform/tensorflow-without-a-phd/master/tensorflow-rl-pong/images/tpu-hexagon.png" width="50"></a></h3>
#
# * On the main menu, click Runtime and select **Change runtime type**. Set "TPU" as the hardware accelerator.
# * The cell below makes sure you have access to a TPU on Colab.

# %%
import os
assert os.environ['COLAB_TPU_ADDR'], 'Make sure to select TPU from Edit > Notebook settings > Hardware accelerator'

# %% [markdown]
# ### [RUNME] Install Colab TPU compatible PyTorch/TPU wheels and dependencies

# %%
# !pip install cloud-tpu-client==0.10 torch==1.12.0 https://storage.googleapis.com/tpu-pytorch/wheels/colab/torch_xla-1.12-cp37-cp37m-linux_x86_64.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-xla==1.12
#   Downloading https://storage.googleapis.com/tpu-pytorch/wheels/colab/torch_xla-1.12-cp37-cp37m-linux_x86_64.whl (187.4 MB)
#      |████████████████████████████████| 187.4 MB 28 kB/s
# Collecting cloud-tpu-client==0.10
#   Downloading cloud_tpu_client-0.10-py3-none-any.whl (7.4 kB)
# Collecting torch==1.12.0
#   Downloading torch-1.12.0-cp37-cp37m-manylinux1_x86_64.whl (776.3 MB)
#      |████████████████████████████████| 776.3 MB 18 kB/s
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from torch-xla==1.12) (1.3.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from cloud-tpu-client==0.10) (4.1.3)
# Collecting google-api-python-client==1.8.0
#   Downloading google_api_python_client-1.8.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.2 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.12.0) (4.1.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.0.4)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.35.0)
# Requirement already satisfied: google-api-core<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.31.6)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.17.4)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.15.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.0.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (2022.5)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (2.23.0)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.17.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (57.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.56.4)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (21.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (4.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.24.3)
# Installing collected packages: google-api-python-client, cloud-tpu-client, torch-xla, torch
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 1.12.11
#     Uninstalling google-api-python-client-1.12.11:
#       Successfully uninstalled google-api-python-client-1.12.11
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.12.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.12.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.12.0 which is incompatible.
# earthengine-api 0.1.329 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 1.8.0 which is incompatible.
# Successfully installed cloud-tpu-client-0.10 google-api-python-client-1.8.0 torch-1.12.0 torch-xla-1.12

# %% [markdown]
# ### If you're using GPU with this colab notebook, run the below commented code to install GPU compatible PyTorch wheel and dependencies

# %%
#!pip install cloud-tpu-client==0.10 torch==1.12.0 https://storage.googleapis.com/tpu-pytorch/wheels/cuda/112/torch_xla-1.12-cp37-cp37m-linux_x86_64.whl --force-reinstall

# %% [markdown]
# ### Only run the below commented cell if you would like a nightly release

# %%
# VERSION = "1.12"  #@param ["1.12", "nightly", "20220315"]  # or YYYYMMDD format
# !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
# !python pytorch-xla-env-setup.py --version $VERSION
# import os 
# os.environ['LD_LIBRARY_PATH']='/usr/local/lib'
# !echo $LD_LIBRARY_PATH

# !sudo ln -s /usr/local/lib/libmkl_intel_lp64.so /usr/local/lib/libmkl_intel_lp64.so.1
# !sudo ln -s /usr/local/lib/libmkl_intel_thread.so /usr/local/lib/libmkl_intel_thread.so.1
# !sudo ln -s /usr/local/lib/libmkl_core.so /usr/local/lib/libmkl_core.so.1

# !ldconfig
# !ldd /usr/local/lib/python3.7/dist-packages/torch/lib/libtorch.so

# %% [markdown]
# ### Define Parameters and Helpers, and start Training

# %%
# Result Visualization Helper
import math
from matplotlib import pyplot as plt

M, N = 4, 6
RESULT_IMG_PATH = '/tmp/test_result.png'

def plot_results(images, labels, preds):
  images, labels, preds = images[:M*N], labels[:M*N], preds[:M*N]
  inv_norm = transforms.Normalize((-0.1307/0.3081,), (1/0.3081,))

  num_images = images.shape[0]
  fig, axes = plt.subplots(M, N, figsize=(11, 9))
  fig.suptitle('Correct / Predicted Labels (Red text for incorrect ones)')

  for i, ax in enumerate(fig.axes):
    ax.axis('off')
    if i >= num_images:
      continue
    img, label, prediction = images[i], labels[i], preds[i]
    img = inv_norm(img)
    img = img.squeeze() # [1,Y,X] -> [Y,X]
    label, prediction = label.item(), prediction.item()
    if label == prediction:
      ax.set_title(u'\u2713', color='blue', fontsize=22)
    else:
      ax.set_title(
          'X {}/{}'.format(label, prediction), color='red')
    ax.imshow(img)
  plt.savefig(RESULT_IMG_PATH, transparent=True)

# %%
# Define Parameters
FLAGS = {}
FLAGS['datadir'] = "/tmp/mnist"
FLAGS['batch_size'] = 128
FLAGS['num_workers'] = 4
FLAGS['learning_rate'] = 0.01
FLAGS['momentum'] = 0.5
FLAGS['num_epochs'] = 10
FLAGS['num_cores'] = 8
FLAGS['log_steps'] = 20
FLAGS['metrics_debug'] = False

# %%
import numpy as np
import os
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch_xla
import torch_xla.core.xla_model as xm
import torch_xla.debug.metrics as met
import torch_xla.distributed.parallel_loader as pl
import torch_xla.distributed.xla_multiprocessing as xmp
import torch_xla.utils.utils as xu
from torchvision import datasets, transforms


SERIAL_EXEC = xmp.MpSerialExecutor()

class MNIST(nn.Module):

  def __init__(self):
    super(MNIST, self).__init__()
    self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
    self.bn1 = nn.BatchNorm2d(10)
    self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
    self.bn2 = nn.BatchNorm2d(20)
    self.fc1 = nn.Linear(320, 50)
    self.fc2 = nn.Linear(50, 10)

  def forward(self, x):
    x = F.relu(F.max_pool2d(self.conv1(x), 2))
    x = self.bn1(x)
    x = F.relu(F.max_pool2d(self.conv2(x), 2))
    x = self.bn2(x)
    x = torch.flatten(x, 1)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return F.log_softmax(x, dim=1)

# Only instantiate model weights once in memory.
WRAPPED_MODEL = xmp.MpModelWrapper(MNIST())

def train_mnist():
  torch.manual_seed(1)
  
  def get_dataset():
    norm = transforms.Normalize((0.1307,), (0.3081,))
    train_dataset = datasets.MNIST(
        FLAGS['datadir'],
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.ToTensor(), norm]))
    test_dataset = datasets.MNIST(
        FLAGS['datadir'],
        train=False,
        download=True,
        transform=transforms.Compose(
            [transforms.ToTensor(), norm]))
    
    return train_dataset, test_dataset
  
  # Using the serial executor avoids multiple processes to
  # download the same data.
  train_dataset, test_dataset = SERIAL_EXEC.run(get_dataset)

  train_sampler = torch.utils.data.distributed.DistributedSampler(
    train_dataset,
    num_replicas=xm.xrt_world_size(),
    rank=xm.get_ordinal(),
    shuffle=True)
  train_loader = torch.utils.data.DataLoader(
      train_dataset,
      batch_size=FLAGS['batch_size'],
      sampler=train_sampler,
      num_workers=FLAGS['num_workers'],
      drop_last=True)
  test_loader = torch.utils.data.DataLoader(
      test_dataset,
      batch_size=FLAGS['batch_size'],
      shuffle=False,
      num_workers=FLAGS['num_workers'],
      drop_last=True)

  # Scale learning rate to world size
  lr = FLAGS['learning_rate'] * xm.xrt_world_size()

  # Get loss function, optimizer, and model
  device = xm.xla_device()
  model = WRAPPED_MODEL.to(device)
  optimizer = optim.SGD(model.parameters(), lr=lr, momentum=FLAGS['momentum'])
  loss_fn = nn.NLLLoss()

  def train_loop_fn(loader):
    tracker = xm.RateTracker()
    model.train()
    for x, (data, target) in enumerate(loader):
      optimizer.zero_grad()
      output = model(data)
      loss = loss_fn(output, target)
      loss.backward()
      xm.optimizer_step(optimizer)
      tracker.add(FLAGS['batch_size'])
      if x % FLAGS['log_steps'] == 0:
        print('[xla:{}]({}) Loss={:.5f} Rate={:.2f} GlobalRate={:.2f} Time={}'.format(
            xm.get_ordinal(), x, loss.item(), tracker.rate(),
            tracker.global_rate(), time.asctime()), flush=True)

  def test_loop_fn(loader):
    total_samples = 0
    correct = 0
    model.eval()
    data, pred, target = None, None, None
    for data, target in loader:
      output = model(data)
      pred = output.max(1, keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()
      total_samples += data.size()[0]

    accuracy = 100.0 * correct / total_samples
    print('[xla:{}] Accuracy={:.2f}%'.format(
        xm.get_ordinal(), accuracy), flush=True)
    return accuracy, data, pred, target

  # Train and eval loops
  accuracy = 0.0
  data, pred, target = None, None, None
  for epoch in range(1, FLAGS['num_epochs'] + 1):
    para_loader = pl.ParallelLoader(train_loader, [device])
    train_loop_fn(para_loader.per_device_loader(device))
    xm.master_print("Finished training epoch {}".format(epoch))

    para_loader = pl.ParallelLoader(test_loader, [device])
    accuracy, data, pred, target  = test_loop_fn(para_loader.per_device_loader(device))
    if FLAGS['metrics_debug']:
      xm.master_print(met.metrics_report(), flush=True)

  return accuracy, data, pred, target
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %%
# Start training processes
def _mp_fn(rank, flags):
  global FLAGS
  FLAGS = flags
  torch.set_default_tensor_type('torch.FloatTensor')
  accuracy, data, pred, target = train_mnist()
  if rank == 0:
    # Retrieve tensors that are on TPU core 0 and plot.
    plot_results(data.cpu(), pred.cpu(), target.cpu())

xmp.spawn(_mp_fn, args=(FLAGS,), nprocs=FLAGS['num_cores'], start_method='fork')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /tmp/mnist/MNIST/raw/train-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /tmp/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /tmp/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /tmp/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:0](0) Loss=2.31373 Rate=62.28 GlobalRate=62.27 Time=Mon Nov  7 08:27:29 2022
# [xla:6](0) Loss=2.30498 Rate=281.46 GlobalRate=281.41 Time=Mon Nov  7 08:27:29 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:5](0) Loss=2.31197 Rate=269.33 GlobalRate=269.30 Time=Mon Nov  7 08:27:30 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:4](0) Loss=2.30840 Rate=323.79 GlobalRate=323.76 Time=Mon Nov  7 08:27:32 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:3](0) Loss=2.30363 Rate=253.97 GlobalRate=253.94 Time=Mon Nov  7 08:27:35 2022
# [xla:2](0) Loss=2.28933 Rate=195.56 GlobalRate=195.55 Time=Mon Nov  7 08:27:35 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:1](0) Loss=2.29972 Rate=315.07 GlobalRate=315.03 Time=Mon Nov  7 08:27:39 2022
# [xla:7](0) Loss=2.31799 Rate=214.39 GlobalRate=214.37 Time=Mon Nov  7 08:27:39 2022
# [xla:0](20) Loss=0.41769 Rate=136.63 GlobalRate=170.08 Time=Mon Nov  7 08:27:43 2022[xla:2](20) Loss=0.38663 Rate=272.04 GlobalRate=313.31 Time=Mon Nov  7 08:27:43 2022[xla:6](20) Loss=0.29933 Rate=227.11 GlobalRate=193.85 Time=Mon Nov  7 08:27:43 2022[xla:3](20) Loss=0.35215 Rate=288.27 GlobalRate=307.84 Time=Mon Nov  7 08:27:43 2022[xla:7](20) Loss=0.35163 Rate=524.03 GlobalRate=655.33 Time=Mon Nov  7 08:27:43 2022[xla:4](20) Loss=0.40875 Rate=267.15 GlobalRate=232.61 Time=Mon Nov  7 08:27:43 2022[xla:1](20) Loss=0.32163 Rate=478.78 GlobalRate=564.63 Time=Mon Nov  7 08:27:43 2022
#
#
#
#
#
#
# [xla:5](20) Loss=0.39342 Rate=229.73 GlobalRate=205.73 Time=Mon Nov  7 08:27:43 2022
# [xla:3](40) Loss=0.24249 Rate=574.58 GlobalRate=434.58 Time=Mon Nov  7 08:27:46 2022
# [xla:2](40) Loss=0.18321 Rate=548.37 GlobalRate=434.66 Time=Mon Nov  7 08:27:46 2022
# [xla:1](40) Loss=0.17122 Rate=624.79 GlobalRate=631.86 Time=Mon Nov  7 08:27:46 2022
# [xla:0](40) Loss=0.23156 Rate=466.54 GlobalRate=268.67 Time=Mon Nov  7 08:27:47 2022[xla:5](40) Loss=0.17719 Rate=526.40 GlobalRate=316.13 Time=Mon Nov  7 08:27:47 2022[xla:4](40) Loss=0.11467 Rate=517.60 GlobalRate=343.11 Time=Mon Nov  7 08:27:47 2022
#
#
# [xla:6](40) Loss=0.21307 Rate=495.54 GlobalRate=297.13 Time=Mon Nov  7 08:27:47 2022
# [xla:7](40) Loss=0.20712 Rate=609.53 GlobalRate=660.75 Time=Mon Nov  7 08:27:47 2022
# Finished training epoch 1
# [xla:7] Accuracy=96.05%
# [xla:3] Accuracy=96.09%
# [xla:5] Accuracy=96.02%
# [xla:6] Accuracy=96.06%
# [xla:4] Accuracy=96.07%[xla:2] Accuracy=96.10%
#
# [xla:0] Accuracy=96.06%
# [xla:1] Accuracy=96.04%
# [xla:3](0) Loss=0.10050 Rate=96.21 GlobalRate=96.21 Time=Mon Nov  7 08:28:11 2022
# [xla:7](0) Loss=0.22002 Rate=83.38 GlobalRate=83.38 Time=Mon Nov  7 08:28:11 2022
# [xla:6](0) Loss=0.19561 Rate=81.79 GlobalRate=81.79 Time=Mon Nov  7 08:28:11 2022
# [xla:5](0) Loss=0.15865 Rate=77.10 GlobalRate=77.10 Time=Mon Nov  7 08:28:12 2022
# [xla:4](0) Loss=0.12963 Rate=75.05 GlobalRate=75.04 Time=Mon Nov  7 08:28:12 2022
# [xla:2](0) Loss=0.14891 Rate=65.45 GlobalRate=65.44 Time=Mon Nov  7 08:28:12 2022
# [xla:1](0) Loss=0.17716 Rate=56.46 GlobalRate=56.46 Time=Mon Nov  7 08:28:13 2022
# [xla:0](0) Loss=0.15424 Rate=51.55 GlobalRate=51.55 Time=Mon Nov  7 08:28:13 2022
# [xla:4](20) Loss=0.13325 Rate=322.58 GlobalRate=386.44 Time=Mon Nov  7 08:28:17 2022
# [xla:5](20) Loss=0.14156 Rate=313.78 GlobalRate=379.18 Time=Mon Nov  7 08:28:17 2022[xla:7](20) Loss=0.14638 Rate=297.97 GlobalRate=366.22 Time=Mon Nov  7 08:28:17 2022[xla:3](20) Loss=0.15630 Rate=300.51 GlobalRate=373.73 Time=Mon Nov  7 08:28:17 2022[xla:6](20) Loss=0.05808 Rate=309.72 GlobalRate=378.06 Time=Mon Nov  7 08:28:17 2022
#
#
#
#
# [xla:2](20) Loss=0.15894 Rate=323.92 GlobalRate=377.81 Time=Mon Nov  7 08:28:17 2022[xla:1](20) Loss=0.08298 Rate=328.03 GlobalRate=368.43 Time=Mon Nov  7 08:28:18 2022
# [xla:0](20) Loss=0.12870 Rate=326.43 GlobalRate=358.11 Time=Mon Nov  7 08:28:18 2022
# [xla:3](40) Loss=0.13481 Rate=428.45 GlobalRate=431.04 Time=Mon Nov  7 08:28:22 2022[xla:6](40) Loss=0.09595 Rate=431.78 GlobalRate=433.76 Time=Mon Nov  7 08:28:22 2022[xla:7](40) Loss=0.10102 Rate=427.17 GlobalRate=425.73 Time=Mon Nov  7 08:28:22 2022[xla:5](40) Loss=0.08053 Rate=433.56 GlobalRate=434.61 Time=Mon Nov  7 08:28:22 2022
#
#
#
# [xla:4](40) Loss=0.03820 Rate=425.61 GlobalRate=432.47 Time=Mon Nov  7 08:28:22 2022
# [xla:2](40) Loss=0.08247 Rate=431.51 GlobalRate=430.10 Time=Mon Nov  7 08:28:22 2022
# [xla:1](40) Loss=0.08725 Rate=432.57 GlobalRate=423.47 Time=Mon Nov  7 08:28:23 2022
# [xla:0](40) Loss=0.13485 Rate=432.17 GlobalRate=416.55 Time=Mon Nov  7 08:28:23 2022
# Finished training epoch 2
# [xla:2] Accuracy=97.67%
# [xla:4] Accuracy=97.67%[xla:1] Accuracy=97.61%
#
# [xla:3] Accuracy=97.65%[xla:6] Accuracy=97.65%
#
# [xla:5] Accuracy=97.64%
# [xla:0] Accuracy=97.69%
# [xla:7] Accuracy=97.67%
# [xla:2](0) Loss=0.09814 Rate=90.15 GlobalRate=90.15 Time=Mon Nov  7 08:28:46 2022
# [xla:4](0) Loss=0.07933 Rate=79.63 GlobalRate=79.63 Time=Mon Nov  7 08:28:47 2022
# [xla:3](0) Loss=0.04531 Rate=83.27 GlobalRate=83.27 Time=Mon Nov  7 08:28:47 2022[xla:6](0) Loss=0.11963 Rate=82.34 GlobalRate=82.34 Time=Mon Nov  7 08:28:47 2022
#
# [xla:1](0) Loss=0.09096 Rate=74.80 GlobalRate=74.80 Time=Mon Nov  7 08:28:47 2022
# [xla:5](0) Loss=0.09044 Rate=72.67 GlobalRate=72.67 Time=Mon Nov  7 08:28:47 2022
# [xla:0](0) Loss=0.09863 Rate=56.03 GlobalRate=56.03 Time=Mon Nov  7 08:28:48 2022
# [xla:7](0) Loss=0.13370 Rate=55.24 GlobalRate=55.24 Time=Mon Nov  7 08:28:48 2022
# [xla:2](20) Loss=0.12068 Rate=315.08 GlobalRate=388.17 Time=Mon Nov  7 08:28:52 2022[xla:1](20) Loss=0.04969 Rate=332.85 GlobalRate=396.36 Time=Mon Nov  7 08:28:52 2022[xla:4](20) Loss=0.07839 Rate=324.66 GlobalRate=392.22 Time=Mon Nov  7 08:28:52 2022[xla:3](20) Loss=0.11384 Rate=329.31 GlobalRate=399.62 Time=Mon Nov  7 08:28:52 2022[xla:6](20) Loss=0.02731 Rate=330.79 GlobalRate=400.51 Time=Mon Nov  7 08:28:52 2022[xla:5](20) Loss=0.10747 Rate=344.61 GlobalRate=405.48 Time=Mon Nov  7 08:28:52 2022
#
#
#
#
#
# [xla:7](20) Loss=0.11659 Rate=332.99 GlobalRate=370.36 Time=Mon Nov  7 08:28:53 2022[xla:0](20) Loss=0.08866 Rate=327.50 GlobalRate=367.25 Time=Mon Nov  7 08:28:53 2022
#
# [xla:2](40) Loss=0.06327 Rate=423.50 GlobalRate=434.14 Time=Mon Nov  7 08:28:57 2022[xla:4](40) Loss=0.02471 Rate=427.36 GlobalRate=436.74 Time=Mon Nov  7 08:28:57 2022[xla:1](40) Loss=0.05979 Rate=430.10 GlobalRate=439.01 Time=Mon Nov  7 08:28:57 2022[xla:6](40) Loss=0.05736 Rate=429.56 GlobalRate=441.79 Time=Mon Nov  7 08:28:57 2022[xla:3](40) Loss=0.09126 Rate=429.38 GlobalRate=441.50 Time=Mon Nov  7 08:28:57 2022
#
#
#
#
# [xla:5](40) Loss=0.05025 Rate=426.38 GlobalRate=439.07 Time=Mon Nov  7 08:28:57 2022
# [xla:0](40) Loss=0.11110 Rate=436.78 GlobalRate=425.20 Time=Mon Nov  7 08:28:58 2022
# [xla:7](40) Loss=0.06684 Rate=426.16 GlobalRate=419.81 Time=Mon Nov  7 08:28:58 2022
# Finished training epoch 3
# [xla:6] Accuracy=98.11%
# [xla:1] Accuracy=98.14%
# [xla:2] Accuracy=98.12%
# [xla:4] Accuracy=98.09%
# [xla:7] Accuracy=98.11%
# [xla:5] Accuracy=98.11%[xla:3] Accuracy=98.12%
#
# [xla:0] Accuracy=98.10%
# [xla:6](0) Loss=0.09115 Rate=72.47 GlobalRate=72.46 Time=Mon Nov  7 08:29:24 2022
# [xla:4](0) Loss=0.06176 Rate=68.55 GlobalRate=68.54 Time=Mon Nov  7 08:29:24 2022
# [xla:1](0) Loss=0.06374 Rate=59.08 GlobalRate=59.08 Time=Mon Nov  7 08:29:24 2022[xla:7](0) Loss=0.09772 Rate=59.54 GlobalRate=59.54 Time=Mon Nov  7 08:29:24 2022
# [xla:2](0) Loss=0.07856 Rate=58.67 GlobalRate=58.66 Time=Mon Nov  7 08:29:24 2022
#
# [xla:5](0) Loss=0.06407 Rate=59.36 GlobalRate=59.36 Time=Mon Nov  7 08:29:24 2022
# [xla:3](0) Loss=0.02997 Rate=55.50 GlobalRate=55.50 Time=Mon Nov  7 08:29:25 2022
# [xla:0](0) Loss=0.07873 Rate=43.98 GlobalRate=43.97 Time=Mon Nov  7 08:29:26 2022
# [xla:2](20) Loss=0.09341 Rate=304.09 GlobalRate=351.13 Time=Mon Nov  7 08:29:30 2022[xla:4](20) Loss=0.05297 Rate=289.32 GlobalRate=347.64 Time=Mon Nov  7 08:29:30 2022[xla:3](20) Loss=0.09093 Rate=313.66 GlobalRate=354.80 Time=Mon Nov  7 08:29:30 2022[xla:5](20) Loss=0.10368 Rate=308.55 GlobalRate=356.05 Time=Mon Nov  7 08:29:30 2022[xla:1](20) Loss=0.03766 Rate=298.72 GlobalRate=346.83 Time=Mon Nov  7 08:29:30 2022[xla:6](20) Loss=0.01710 Rate=277.42 GlobalRate=338.16 Time=Mon Nov  7 08:29:30 2022[xla:7](20) Loss=0.10044 Rate=299.48 GlobalRate=348.10 Time=Mon Nov  7 08:29:30 2022
#
#
#
#
#
#
# [xla:0](20) Loss=0.07937 Rate=314.91 GlobalRate=332.80 Time=Mon Nov  7 08:29:31 2022
# [xla:4](40) Loss=0.02008 Rate=399.18 GlobalRate=399.06 Time=Mon Nov  7 08:29:35 2022[xla:7](40) Loss=0.04853 Rate=402.82 GlobalRate=399.12 Time=Mon Nov  7 08:29:35 2022[xla:1](40) Loss=0.04573 Rate=403.56 GlobalRate=398.86 Time=Mon Nov  7 08:29:35 2022[xla:3](40) Loss=0.07143 Rate=409.67 GlobalRate=404.29 Time=Mon Nov  7 08:29:35 2022[xla:6](40) Loss=0.04061 Rate=394.68 GlobalRate=392.73 Time=Mon Nov  7 08:29:35 2022
# [xla:5](40) Loss=0.03409 Rate=406.48 GlobalRate=404.44 Time=Mon Nov  7 08:29:35 2022
# [xla:2](40) Loss=0.05364 Rate=406.33 GlobalRate=402.13 Time=Mon Nov  7 08:29:35 2022
#
#
#
#
# [xla:0](40) Loss=0.10202 Rate=418.34 GlobalRate=393.69 Time=Mon Nov  7 08:29:36 2022
# Finished training epoch 4
# [xla:2] Accuracy=98.38%[xla:6] Accuracy=98.40%[xla:5] Accuracy=98.41%
#
#
# [xla:4] Accuracy=98.39%[xla:7] Accuracy=98.41%[xla:0] Accuracy=98.39%
#
# [xla:1] Accuracy=98.48%
#
# [xla:3] Accuracy=98.39%
# [xla:5](0) Loss=0.05155 Rate=100.04 GlobalRate=100.04 Time=Mon Nov  7 08:30:00 2022
# [xla:2](0) Loss=0.06790 Rate=95.06 GlobalRate=95.06 Time=Mon Nov  7 08:30:00 2022
# [xla:6](0) Loss=0.07450 Rate=71.02 GlobalRate=71.02 Time=Mon Nov  7 08:30:01 2022
# [xla:7](0) Loss=0.07699 Rate=68.00 GlobalRate=68.00 Time=Mon Nov  7 08:30:01 2022
# [xla:4](0) Loss=0.05447 Rate=59.61 GlobalRate=59.61 Time=Mon Nov  7 08:30:01 2022
# [xla:1](0) Loss=0.05310 Rate=55.37 GlobalRate=55.37 Time=Mon Nov  7 08:30:01 2022[xla:3](0) Loss=0.02250 Rate=55.27 GlobalRate=55.27 Time=Mon Nov  7 08:30:01 2022
#
# [xla:0](0) Loss=0.06822 Rate=50.21 GlobalRate=50.21 Time=Mon Nov  7 08:30:02 2022
# [xla:2](20) Loss=0.07160 Rate=300.95 GlobalRate=373.93 Time=Mon Nov  7 08:30:06 2022[xla:5](20) Loss=0.09880 Rate=300.60 GlobalRate=374.69 Time=Mon Nov  7 08:30:06 2022
#
# [xla:7](20) Loss=0.09162 Rate=323.16 GlobalRate=380.09 Time=Mon Nov  7 08:30:06 2022
# [xla:6](20) Loss=0.01191 Rate=306.50 GlobalRate=366.93 Time=Mon Nov  7 08:30:06 2022
# [xla:4](20) Loss=0.03847 Rate=319.56 GlobalRate=366.14 Time=Mon Nov  7 08:30:06 2022
# [xla:3](20) Loss=0.07834 Rate=312.13 GlobalRate=353.13 Time=Mon Nov  7 08:30:07 2022[xla:1](20) Loss=0.02949 Rate=310.78 GlobalRate=352.13 Time=Mon Nov  7 08:30:07 2022
#
# [xla:0](20) Loss=0.07586 Rate=310.43 GlobalRate=342.88 Time=Mon Nov  7 08:30:07 2022
# [xla:6](40) Loss=0.03221 Rate=408.89 GlobalRate=413.53 Time=Mon Nov  7 08:30:12 2022[xla:2](40) Loss=0.04937 Rate=400.44 GlobalRate=414.11 Time=Mon Nov  7 08:30:12 2022
#
# [xla:7](40) Loss=0.03920 Rate=405.59 GlobalRate=415.49 Time=Mon Nov  7 08:30:12 2022
# [xla:5](40) Loss=0.02485 Rate=388.46 GlobalRate=406.81 Time=Mon Nov  7 08:30:12 2022
# [xla:3](40) Loss=0.06148 Rate=410.23 GlobalRate=403.87 Time=Mon Nov  7 08:30:12 2022
# [xla:0](40) Loss=0.09553 Rate=415.11 GlobalRate=400.03 Time=Mon Nov  7 08:30:12 2022
# [xla:4](40) Loss=0.01681 Rate=387.76 GlobalRate=396.06 Time=Mon Nov  7 08:30:12 2022
# [xla:1](40) Loss=0.03750 Rate=386.35 GlobalRate=388.88 Time=Mon Nov  7 08:30:13 2022
# Finished training epoch 5
# [xla:2] Accuracy=98.61%
# [xla:3] Accuracy=98.61%
# [xla:5] Accuracy=98.61%
# [xla:0] Accuracy=98.61%
# [xla:7] Accuracy=98.63%
# [xla:4] Accuracy=98.61%
# [xla:6] Accuracy=98.61%
# [xla:1] Accuracy=98.61%
# [xla:5](0) Loss=0.04286 Rate=83.17 GlobalRate=83.17 Time=Mon Nov  7 08:30:38 2022
# [xla:3](0) Loss=0.01893 Rate=77.05 GlobalRate=77.05 Time=Mon Nov  7 08:30:38 2022
# [xla:2](0) Loss=0.06207 Rate=71.19 GlobalRate=71.19 Time=Mon Nov  7 08:30:38 2022
# [xla:1](0) Loss=0.04404 Rate=69.47 GlobalRate=69.47 Time=Mon Nov  7 08:30:39 2022
# [xla:0](0) Loss=0.05912 Rate=57.83 GlobalRate=57.83 Time=Mon Nov  7 08:30:39 2022[xla:4](0) Loss=0.04968 Rate=63.29 GlobalRate=63.28 Time=Mon Nov  7 08:30:39 2022
# [xla:7](0) Loss=0.06472 Rate=58.52 GlobalRate=58.52 Time=Mon Nov  7 08:30:39 2022
#
# [xla:6](0) Loss=0.06135 Rate=57.25 GlobalRate=57.25 Time=Mon Nov  7 08:30:39 2022
# [xla:2](20) Loss=0.06210 Rate=318.36 GlobalRate=378.77 Time=Mon Nov  7 08:30:44 2022[xla:5](20) Loss=0.09598 Rate=316.27 GlobalRate=385.84 Time=Mon Nov  7 08:30:44 2022
#
# [xla:3](20) Loss=0.06999 Rate=305.18 GlobalRate=370.26 Time=Mon Nov  7 08:30:44 2022
# [xla:7](20) Loss=0.08588 Rate=313.80 GlobalRate=359.51 Time=Mon Nov  7 08:30:44 2022[xla:1](20) Loss=0.02403 Rate=307.75 GlobalRate=366.76 Time=Mon Nov  7 08:30:44 2022
#
# [xla:6](20) Loss=0.00867 Rate=318.50 GlobalRate=361.68 Time=Mon Nov  7 08:30:44 2022[xla:0](20) Loss=0.07375 Rate=301.41 GlobalRate=347.59 Time=Mon Nov  7 08:30:44 2022[xla:4](20) Loss=0.03080 Rate=303.84 GlobalRate=356.62 Time=Mon Nov  7 08:30:44 2022
#
#
# [xla:5](40) Loss=0.01914 Rate=399.77 GlobalRate=416.92 Time=Mon Nov  7 08:30:49 2022[xla:3](40) Loss=0.05401 Rate=405.51 GlobalRate=413.92 Time=Mon Nov  7 08:30:49 2022[xla:2](40) Loss=0.04858 Rate=400.19 GlobalRate=412.38 Time=Mon Nov  7 08:30:49 2022
#
#
# [xla:1](40) Loss=0.03129 Rate=412.16 GlobalRate=415.10 Time=Mon Nov  7 08:30:50 2022
# [xla:0](40) Loss=0.09039 Rate=408.05 GlobalRate=401.35 Time=Mon Nov  7 08:30:50 2022
# [xla:6](40) Loss=0.02787 Rate=408.18 GlobalRate=406.74 Time=Mon Nov  7 08:30:50 2022
# [xla:7](40) Loss=0.03415 Rate=396.19 GlobalRate=399.04 Time=Mon Nov  7 08:30:50 2022
# [xla:4](40) Loss=0.01360 Rate=394.49 GlobalRate=398.64 Time=Mon Nov  7 08:30:50 2022
# Finished training epoch 6
# [xla:1] Accuracy=98.74%[xla:3] Accuracy=98.70%[xla:0] Accuracy=98.71%[xla:6] Accuracy=98.70%
#
#
#
# [xla:2] Accuracy=98.71%[xla:4] Accuracy=98.71%[xla:5] Accuracy=98.71%[xla:7] Accuracy=98.72%
#
#
#
# [xla:3](0) Loss=0.01686 Rate=132.61 GlobalRate=132.60 Time=Mon Nov  7 08:31:15 2022
# [xla:6](0) Loss=0.05356 Rate=76.25 GlobalRate=76.25 Time=Mon Nov  7 08:31:16 2022
# [xla:1](0) Loss=0.03661 Rate=77.53 GlobalRate=77.53 Time=Mon Nov  7 08:31:16 2022
# [xla:0](0) Loss=0.05150 Rate=67.13 GlobalRate=67.13 Time=Mon Nov  7 08:31:16 2022
# [xla:7](0) Loss=0.05710 Rate=69.73 GlobalRate=69.73 Time=Mon Nov  7 08:31:16 2022
# [xla:4](0) Loss=0.04649 Rate=59.10 GlobalRate=59.10 Time=Mon Nov  7 08:31:16 2022[xla:2](0) Loss=0.05851 Rate=58.86 GlobalRate=58.86 Time=Mon Nov  7 08:31:16 2022
#
# [xla:5](0) Loss=0.03722 Rate=56.95 GlobalRate=56.95 Time=Mon Nov  7 08:31:16 2022
# [xla:1](20) Loss=0.01946 Rate=330.33 GlobalRate=396.31 Time=Mon Nov  7 08:31:21 2022[xla:6](20) Loss=0.00713 Rate=330.53 GlobalRate=395.41 Time=Mon Nov  7 08:31:21 2022[xla:3](20) Loss=0.06507 Rate=316.31 GlobalRate=395.32 Time=Mon Nov  7 08:31:21 2022
#
#
# [xla:7](20) Loss=0.07991 Rate=326.27 GlobalRate=384.91 Time=Mon Nov  7 08:31:21 2022[xla:0](20) Loss=0.07114 Rate=321.37 GlobalRate=377.42 Time=Mon Nov  7 08:31:21 2022
#
# [xla:4](20) Loss=0.02544 Rate=330.92 GlobalRate=375.17 Time=Mon Nov  7 08:31:21 2022
# [xla:5](20) Loss=0.08990 Rate=325.95 GlobalRate=367.51 Time=Mon Nov  7 08:31:21 2022
# [xla:2](20) Loss=0.05529 Rate=311.18 GlobalRate=357.70 Time=Mon Nov  7 08:31:22 2022
# [xla:1](40) Loss=0.02754 Rate=427.10 GlobalRate=437.70 Time=Mon Nov  7 08:31:26 2022[xla:3](40) Loss=0.04865 Rate=421.11 GlobalRate=436.84 Time=Mon Nov  7 08:31:26 2022[xla:6](40) Loss=0.02482 Rate=427.24 GlobalRate=437.17 Time=Mon Nov  7 08:31:26 2022
#
#
# [xla:7](40) Loss=0.02959 Rate=430.84 GlobalRate=433.80 Time=Mon Nov  7 08:31:26 2022
# [xla:5](40) Loss=0.01605 Rate=435.38 GlobalRate=424.93 Time=Mon Nov  7 08:31:26 2022[xla:4](40) Loss=0.01181 Rate=427.88 GlobalRate=424.51 Time=Mon Nov  7 08:31:26 2022[xla:0](40) Loss=0.08542 Rate=412.10 GlobalRate=418.53 Time=Mon Nov  7 08:31:27 2022
#
#
# [xla:2](40) Loss=0.04729 Rate=417.52 GlobalRate=411.41 Time=Mon Nov  7 08:31:27 2022
# Finished training epoch 7
# [xla:6] Accuracy=98.77%[xla:3] Accuracy=98.79%
#
# [xla:5] Accuracy=98.80%[xla:4] Accuracy=98.77%
#
# [xla:2] Accuracy=98.75%[xla:7] Accuracy=98.80%[xla:1] Accuracy=98.83%
#
#
# [xla:0] Accuracy=98.78%
# [xla:3](0) Loss=0.01453 Rate=97.03 GlobalRate=97.03 Time=Mon Nov  7 08:31:51 2022
# [xla:6](0) Loss=0.04643 Rate=92.13 GlobalRate=92.13 Time=Mon Nov  7 08:31:51 2022
# [xla:4](0) Loss=0.04194 Rate=80.92 GlobalRate=80.92 Time=Mon Nov  7 08:31:51 2022
# [xla:7](0) Loss=0.05402 Rate=68.16 GlobalRate=68.16 Time=Mon Nov  7 08:31:51 2022
# [xla:5](0) Loss=0.03175 Rate=64.13 GlobalRate=64.12 Time=Mon Nov  7 08:31:52 2022[xla:1](0) Loss=0.03124 Rate=64.83 GlobalRate=64.83 Time=Mon Nov  7 08:31:52 2022[xla:2](0) Loss=0.05631 Rate=63.94 GlobalRate=63.94 Time=Mon Nov  7 08:31:52 2022
#
#
# [xla:0](0) Loss=0.04527 Rate=55.03 GlobalRate=55.03 Time=Mon Nov  7 08:31:52 2022
# [xla:4](20) Loss=0.02225 Rate=317.02 GlobalRate=385.22 Time=Mon Nov  7 08:31:56 2022[xla:3](20) Loss=0.06111 Rate=298.98 GlobalRate=372.14 Time=Mon Nov  7 08:31:56 2022[xla:7](20) Loss=0.07463 Rate=333.90 GlobalRate=390.29 Time=Mon Nov  7 08:31:57 2022
# [xla:6](20) Loss=0.00606 Rate=299.68 GlobalRate=371.61 Time=Mon Nov  7 08:31:57 2022
#
#
# [xla:1](20) Loss=0.01592 Rate=332.91 GlobalRate=385.20 Time=Mon Nov  7 08:31:57 2022[xla:5](20) Loss=0.08456 Rate=330.84 GlobalRate=382.41 Time=Mon Nov  7 08:31:57 2022
#
# [xla:2](20) Loss=0.05013 Rate=324.24 GlobalRate=376.21 Time=Mon Nov  7 08:31:57 2022
# [xla:0](20) Loss=0.06578 Rate=315.25 GlobalRate=355.36 Time=Mon Nov  7 08:31:57 2022
# [xla:3](40) Loss=0.04583 Rate=412.68 GlobalRate=421.05 Time=Mon Nov  7 08:32:02 2022[xla:6](40) Loss=0.02304 Rate=413.15 GlobalRate=420.82 Time=Mon Nov  7 08:32:02 2022[xla:4](40) Loss=0.01015 Rate=419.59 GlobalRate=429.32 Time=Mon Nov  7 08:32:02 2022[xla:5](40) Loss=0.01325 Rate=430.89 GlobalRate=431.09 Time=Mon Nov  7 08:32:02 2022[xla:7](40) Loss=0.02785 Rate=423.47 GlobalRate=430.68 Time=Mon Nov  7 08:32:02 2022
#
#
#
#
# [xla:2](40) Loss=0.04824 Rate=425.87 GlobalRate=425.60 Time=Mon Nov  7 08:32:02 2022
# [xla:1](40) Loss=0.02411 Rate=416.38 GlobalRate=423.17 Time=Mon Nov  7 08:32:02 2022
# [xla:0](40) Loss=0.08204 Rate=418.20 GlobalRate=409.27 Time=Mon Nov  7 08:32:03 2022
# Finished training epoch 8
# [xla:6] Accuracy=98.88%[xla:1] Accuracy=98.87%
#
# [xla:2] Accuracy=98.89%[xla:4] Accuracy=98.86%[xla:3] Accuracy=98.87%[xla:5] Accuracy=98.88%
#
#
#
# [xla:0] Accuracy=98.90%[xla:7] Accuracy=98.88%
#
# [xla:6](0) Loss=0.03913 Rate=118.54 GlobalRate=118.53 Time=Mon Nov  7 08:32:26 2022
# [xla:1](0) Loss=0.02772 Rate=75.14 GlobalRate=75.14 Time=Mon Nov  7 08:32:27 2022
# [xla:2](0) Loss=0.05378 Rate=71.15 GlobalRate=71.15 Time=Mon Nov  7 08:32:27 2022
# [xla:0](0) Loss=0.04146 Rate=68.50 GlobalRate=68.50 Time=Mon Nov  7 08:32:27 2022
# [xla:3](0) Loss=0.01236 Rate=63.30 GlobalRate=63.30 Time=Mon Nov  7 08:32:27 2022[xla:4](0) Loss=0.04003 Rate=63.62 GlobalRate=63.62 Time=Mon Nov  7 08:32:27 2022[xla:5](0) Loss=0.02725 Rate=62.73 GlobalRate=62.73 Time=Mon Nov  7 08:32:27 2022
#
#
# [xla:7](0) Loss=0.05015 Rate=62.35 GlobalRate=62.34 Time=Mon Nov  7 08:32:27 2022
# [xla:6](20) Loss=0.00516 Rate=326.47 GlobalRate=408.26 Time=Mon Nov  7 08:32:32 2022
# [xla:1](20) Loss=0.01235 Rate=328.42 GlobalRate=392.32 Time=Mon Nov  7 08:32:32 2022
# [xla:2](20) Loss=0.04436 Rate=333.15 GlobalRate=392.97 Time=Mon Nov  7 08:32:32 2022
# [xla:0](20) Loss=0.06187 Rate=331.98 GlobalRate=388.91 Time=Mon Nov  7 08:32:32 2022[xla:3](20) Loss=0.05836 Rate=336.76 GlobalRate=386.54 Time=Mon Nov  7 08:32:32 2022
#
# [xla:4](20) Loss=0.02066 Rate=330.81 GlobalRate=381.70 Time=Mon Nov  7 08:32:32 2022
# [xla:5](20) Loss=0.08099 Rate=317.30 GlobalRate=368.37 Time=Mon Nov  7 08:32:33 2022[xla:7](20) Loss=0.06790 Rate=322.28 GlobalRate=372.35 Time=Mon Nov  7 08:32:33 2022
#
# [xla:6](40) Loss=0.02085 Rate=419.34 GlobalRate=440.88 Time=Mon Nov  7 08:32:37 2022
# [xla:1](40) Loss=0.02096 Rate=420.07 GlobalRate=431.15 Time=Mon Nov  7 08:32:37 2022[xla:4](40) Loss=0.00845 Rate=444.23 GlobalRate=438.55 Time=Mon Nov  7 08:32:37 2022[xla:2](40) Loss=0.04561 Rate=431.60 GlobalRate=437.75 Time=Mon Nov  7 08:32:37 2022
# [xla:3](40) Loss=0.03949 Rate=438.23 GlobalRate=436.80 Time=Mon Nov  7 08:32:37 2022
#
#
# [xla:0](40) Loss=0.07853 Rate=420.69 GlobalRate=428.52 Time=Mon Nov  7 08:32:38 2022
# [xla:7](40) Loss=0.02501 Rate=416.91 GlobalRate=418.09 Time=Mon Nov  7 08:32:38 2022[xla:5](40) Loss=0.01130 Rate=412.87 GlobalRate=414.25 Time=Mon Nov  7 08:32:38 2022
#
# Finished training epoch 9
# [xla:6] Accuracy=98.88%
# [xla:2] Accuracy=98.90%[xla:5] Accuracy=98.90%
#
# [xla:7] Accuracy=98.91%[xla:4] Accuracy=98.91%
#
# [xla:0] Accuracy=98.91%
# [xla:3] Accuracy=98.89%
# [xla:1] Accuracy=98.87%
# [xla:6](0) Loss=0.03331 Rate=98.46 GlobalRate=98.45 Time=Mon Nov  7 08:33:02 2022
# [xla:2](0) Loss=0.04900 Rate=92.64 GlobalRate=92.64 Time=Mon Nov  7 08:33:02 2022
# [xla:5](0) Loss=0.02212 Rate=80.75 GlobalRate=80.75 Time=Mon Nov  7 08:33:02 2022
# [xla:4](0) Loss=0.03724 Rate=74.52 GlobalRate=74.52 Time=Mon Nov  7 08:33:02 2022
# [xla:7](0) Loss=0.04793 Rate=62.40 GlobalRate=62.40 Time=Mon Nov  7 08:33:03 2022
# [xla:3](0) Loss=0.01096 Rate=62.32 GlobalRate=62.32 Time=Mon Nov  7 08:33:03 2022[xla:0](0) Loss=0.03705 Rate=61.53 GlobalRate=61.53 Time=Mon Nov  7 08:33:03 2022
#
# [xla:1](0) Loss=0.02452 Rate=60.70 GlobalRate=60.70 Time=Mon Nov  7 08:33:03 2022
# [xla:2](20) Loss=0.03961 Rate=331.54 GlobalRate=407.42 Time=Mon Nov  7 08:33:07 2022[xla:6](20) Loss=0.00472 Rate=316.85 GlobalRate=393.22 Time=Mon Nov  7 08:33:07 2022
# [xla:5](20) Loss=0.07609 Rate=336.86 GlobalRate=405.52 Time=Mon Nov  7 08:33:07 2022
#
# [xla:4](20) Loss=0.01976 Rate=332.93 GlobalRate=396.17 Time=Mon Nov  7 08:33:08 2022
# [xla:7](20) Loss=0.06465 Rate=335.06 GlobalRate=383.75 Time=Mon Nov  7 08:33:08 2022
# [xla:1](20) Loss=0.00998 Rate=335.31 GlobalRate=381.43 Time=Mon Nov  7 08:33:08 2022[xla:3](20) Loss=0.05561 Rate=323.77 GlobalRate=373.66 Time=Mon Nov  7 08:33:08 2022
#
# [xla:0](20) Loss=0.05700 Rate=320.43 GlobalRate=369.60 Time=Mon Nov  7 08:33:08 2022
# [xla:2](40) Loss=0.04202 Rate=423.68 GlobalRate=441.95 Time=Mon Nov  7 08:33:13 2022[xla:5](40) Loss=0.00996 Rate=428.56 GlobalRate=442.64 Time=Mon Nov  7 08:33:13 2022[xla:6](40) Loss=0.01934 Rate=417.20 GlobalRate=432.86 Time=Mon Nov  7 08:33:13 2022
#
#
# [xla:4](40) Loss=0.00773 Rate=423.19 GlobalRate=434.39 Time=Mon Nov  7 08:33:13 2022
# [xla:7](40) Loss=0.02294 Rate=427.74 GlobalRate=428.97 Time=Mon Nov  7 08:33:13 2022
# [xla:3](40) Loss=0.03552 Rate=426.89 GlobalRate=424.64 Time=Mon Nov  7 08:33:13 2022
# [xla:0](40) Loss=0.07333 Rate=424.42 GlobalRate=421.27 Time=Mon Nov  7 08:33:13 2022
# [xla:1](40) Loss=0.01889 Rate=412.80 GlobalRate=417.87 Time=Mon Nov  7 08:33:14 2022
# Finished training epoch 10
# [xla:1] Accuracy=98.93%
# [xla:5] Accuracy=98.94%
# [xla:7] Accuracy=98.96%[xla:4] Accuracy=98.94%[xla:6] Accuracy=98.94%[xla:3] Accuracy=98.93%[xla:0] Accuracy=98.94%
#
#
# [xla:2] Accuracy=98.93%

# %% [markdown]
# ## Visualize Predictions

# %%
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread(RESULT_IMG_PATH, cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=792x648 at 0x7F3F8B36B210>
