# %% [markdown]
# ## PyTorch/TPU MNIST Demo
#
# This colab example corresponds to the implementation under [test_train_mp_mnist.py](https://github.com/pytorch/xla/blob/master/test/test_train_mp_mnist.py).

# %% [markdown]
# <h3>  &nbsp;&nbsp;Use Colab Cloud TPU&nbsp;&nbsp; <a href="https://cloud.google.com/tpu/"><img valign="middle" src="https://raw.githubusercontent.com/GoogleCloudPlatform/tensorflow-without-a-phd/master/tensorflow-rl-pong/images/tpu-hexagon.png" width="50"></a></h3>
#
# * On the main menu, click Runtime and select **Change runtime type**. Set "TPU" as the hardware accelerator.
# * The cell below makes sure you have access to a TPU on Colab.

# %%
import os
assert os.environ['COLAB_TPU_ADDR'], 'Make sure to select TPU from Edit > Notebook settings > Hardware accelerator'

# %% [markdown]
# ### [RUNME] Install Colab TPU compatible PyTorch/TPU wheels and dependencies

# %%
# !pip install cloud-tpu-client==0.10 torch==1.12.0 https://storage.googleapis.com/tpu-pytorch/wheels/colab/torch_xla-1.12-cp37-cp37m-linux_x86_64.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-xla==1.12
#   Downloading https://storage.googleapis.com/tpu-pytorch/wheels/colab/torch_xla-1.12-cp37-cp37m-linux_x86_64.whl (187.4 MB)
#      |████████████████████████████████| 187.4 MB 26 kB/s
# Collecting cloud-tpu-client==0.10
#   Downloading cloud_tpu_client-0.10-py3-none-any.whl (7.4 kB)
# Collecting torch==1.12.0
#   Downloading torch-1.12.0-cp37-cp37m-manylinux1_x86_64.whl (776.3 MB)
#      |████████████████████████████████| 776.3 MB 18 kB/s
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from torch-xla==1.12) (1.3.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from cloud-tpu-client==0.10) (4.1.3)
# Collecting google-api-python-client==1.8.0
#   Downloading google_api_python_client-1.8.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.12.0) (4.1.1)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.15.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.0.4)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.17.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.0.1)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.35.0)
# Requirement already satisfied: google-api-core<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.31.6)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (57.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.56.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (2.23.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (21.3)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.17.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (2022.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (4.2.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (2022.9.24)
# Installing collected packages: google-api-python-client, cloud-tpu-client, torch-xla, torch
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 1.12.11
#     Uninstalling google-api-python-client-1.12.11:
#       Successfully uninstalled google-api-python-client-1.12.11
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.12.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.12.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.12.0 which is incompatible.
# earthengine-api 0.1.330 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 1.8.0 which is incompatible.
# Successfully installed cloud-tpu-client-0.10 google-api-python-client-1.8.0 torch-1.12.0 torch-xla-1.12

# %% [markdown]
# ### If you're using GPU with this colab notebook, run the below commented code to install GPU compatible PyTorch wheel and dependencies

# %%
#!pip install cloud-tpu-client==0.10 torch==1.12.0 https://storage.googleapis.com/tpu-pytorch/wheels/cuda/112/torch_xla-1.12-cp37-cp37m-linux_x86_64.whl --force-reinstall

# %% [markdown]
# ### Only run the below commented cell if you would like a nightly release

# %%
# VERSION = "1.12"  #@param ["1.12", "nightly", "20220315"]  # or YYYYMMDD format
# !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
# !python pytorch-xla-env-setup.py --version $VERSION
# import os 
# os.environ['LD_LIBRARY_PATH']='/usr/local/lib'
# !echo $LD_LIBRARY_PATH

# !sudo ln -s /usr/local/lib/libmkl_intel_lp64.so /usr/local/lib/libmkl_intel_lp64.so.1
# !sudo ln -s /usr/local/lib/libmkl_intel_thread.so /usr/local/lib/libmkl_intel_thread.so.1
# !sudo ln -s /usr/local/lib/libmkl_core.so /usr/local/lib/libmkl_core.so.1

# !ldconfig
# !ldd /usr/local/lib/python3.7/dist-packages/torch/lib/libtorch.so

# %% [markdown]
# ### Define Parameters and Helpers, and start Training

# %%
# Result Visualization Helper
import math
from matplotlib import pyplot as plt

M, N = 4, 6
RESULT_IMG_PATH = '/tmp/test_result.png'

def plot_results(images, labels, preds):
  images, labels, preds = images[:M*N], labels[:M*N], preds[:M*N]
  inv_norm = transforms.Normalize((-0.1307/0.3081,), (1/0.3081,))

  num_images = images.shape[0]
  fig, axes = plt.subplots(M, N, figsize=(11, 9))
  fig.suptitle('Correct / Predicted Labels (Red text for incorrect ones)')

  for i, ax in enumerate(fig.axes):
    ax.axis('off')
    if i >= num_images:
      continue
    img, label, prediction = images[i], labels[i], preds[i]
    img = inv_norm(img)
    img = img.squeeze() # [1,Y,X] -> [Y,X]
    label, prediction = label.item(), prediction.item()
    if label == prediction:
      ax.set_title(u'\u2713', color='blue', fontsize=22)
    else:
      ax.set_title(
          'X {}/{}'.format(label, prediction), color='red')
    ax.imshow(img)
  plt.savefig(RESULT_IMG_PATH, transparent=True)

# %%
# Define Parameters
FLAGS = {}
FLAGS['datadir'] = "/tmp/mnist"
FLAGS['batch_size'] = 128
FLAGS['num_workers'] = 4
FLAGS['learning_rate'] = 0.01
FLAGS['momentum'] = 0.5
FLAGS['num_epochs'] = 10
FLAGS['num_cores'] = 8
FLAGS['log_steps'] = 20
FLAGS['metrics_debug'] = False

# %%
import numpy as np
import os
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch_xla
import torch_xla.core.xla_model as xm
import torch_xla.debug.metrics as met
import torch_xla.distributed.parallel_loader as pl
import torch_xla.distributed.xla_multiprocessing as xmp
import torch_xla.utils.utils as xu
from torchvision import datasets, transforms


SERIAL_EXEC = xmp.MpSerialExecutor()

class MNIST(nn.Module):

  def __init__(self):
    super(MNIST, self).__init__()
    self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
    self.bn1 = nn.BatchNorm2d(10)
    self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
    self.bn2 = nn.BatchNorm2d(20)
    self.fc1 = nn.Linear(320, 50)
    self.fc2 = nn.Linear(50, 10)

  def forward(self, x):
    x = F.relu(F.max_pool2d(self.conv1(x), 2))
    x = self.bn1(x)
    x = F.relu(F.max_pool2d(self.conv2(x), 2))
    x = self.bn2(x)
    x = torch.flatten(x, 1)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return F.log_softmax(x, dim=1)

# Only instantiate model weights once in memory.
WRAPPED_MODEL = xmp.MpModelWrapper(MNIST())

def train_mnist():
  torch.manual_seed(1)
  
  def get_dataset():
    norm = transforms.Normalize((0.1307,), (0.3081,))
    train_dataset = datasets.MNIST(
        FLAGS['datadir'],
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.ToTensor(), norm]))
    test_dataset = datasets.MNIST(
        FLAGS['datadir'],
        train=False,
        download=True,
        transform=transforms.Compose(
            [transforms.ToTensor(), norm]))
    
    return train_dataset, test_dataset
  
  # Using the serial executor avoids multiple processes to
  # download the same data.
  train_dataset, test_dataset = SERIAL_EXEC.run(get_dataset)

  train_sampler = torch.utils.data.distributed.DistributedSampler(
    train_dataset,
    num_replicas=xm.xrt_world_size(),
    rank=xm.get_ordinal(),
    shuffle=True)
  train_loader = torch.utils.data.DataLoader(
      train_dataset,
      batch_size=FLAGS['batch_size'],
      sampler=train_sampler,
      num_workers=FLAGS['num_workers'],
      drop_last=True)
  test_loader = torch.utils.data.DataLoader(
      test_dataset,
      batch_size=FLAGS['batch_size'],
      shuffle=False,
      num_workers=FLAGS['num_workers'],
      drop_last=True)

  # Scale learning rate to world size
  lr = FLAGS['learning_rate'] * xm.xrt_world_size()

  # Get loss function, optimizer, and model
  device = xm.xla_device()
  model = WRAPPED_MODEL.to(device)
  optimizer = optim.SGD(model.parameters(), lr=lr, momentum=FLAGS['momentum'])
  loss_fn = nn.NLLLoss()

  def train_loop_fn(loader):
    tracker = xm.RateTracker()
    model.train()
    for x, (data, target) in enumerate(loader):
      optimizer.zero_grad()
      output = model(data)
      loss = loss_fn(output, target)
      loss.backward()
      xm.optimizer_step(optimizer)
      tracker.add(FLAGS['batch_size'])
      if x % FLAGS['log_steps'] == 0:
        print('[xla:{}]({}) Loss={:.5f} Rate={:.2f} GlobalRate={:.2f} Time={}'.format(
            xm.get_ordinal(), x, loss.item(), tracker.rate(),
            tracker.global_rate(), time.asctime()), flush=True)

  def test_loop_fn(loader):
    total_samples = 0
    correct = 0
    model.eval()
    data, pred, target = None, None, None
    for data, target in loader:
      output = model(data)
      pred = output.max(1, keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()
      total_samples += data.size()[0]

    accuracy = 100.0 * correct / total_samples
    print('[xla:{}] Accuracy={:.2f}%'.format(
        xm.get_ordinal(), accuracy), flush=True)
    return accuracy, data, pred, target

  # Train and eval loops
  accuracy = 0.0
  data, pred, target = None, None, None
  for epoch in range(1, FLAGS['num_epochs'] + 1):
    para_loader = pl.ParallelLoader(train_loader, [device])
    train_loop_fn(para_loader.per_device_loader(device))
    xm.master_print("Finished training epoch {}".format(epoch))

    para_loader = pl.ParallelLoader(test_loader, [device])
    accuracy, data, pred, target  = test_loop_fn(para_loader.per_device_loader(device))
    if FLAGS['metrics_debug']:
      xm.master_print(met.metrics_report(), flush=True)

  return accuracy, data, pred, target
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %%
# Start training processes
def _mp_fn(rank, flags):
  global FLAGS
  FLAGS = flags
  torch.set_default_tensor_type('torch.FloatTensor')
  accuracy, data, pred, target = train_mnist()
  if rank == 0:
    # Retrieve tensors that are on TPU core 0 and plot.
    plot_results(data.cpu(), pred.cpu(), target.cpu())

xmp.spawn(_mp_fn, args=(FLAGS,), nprocs=FLAGS['num_cores'],
          start_method='fork')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /tmp/mnist/MNIST/raw/train-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /tmp/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /tmp/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /tmp/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:0](0) Loss=2.31537 Rate=60.83 GlobalRate=60.83 Time=Wed Nov  9 06:18:50 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:1](0) Loss=2.29379 Rate=231.80 GlobalRate=231.79 Time=Wed Nov  9 06:18:54 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:7](0) Loss=2.31784 Rate=193.44 GlobalRate=193.42 Time=Wed Nov  9 06:18:55 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:5](0) Loss=2.31846 Rate=156.34 GlobalRate=156.34 Time=Wed Nov  9 06:18:57 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:3](0) Loss=2.29455 Rate=193.86 GlobalRate=193.85 Time=Wed Nov  9 06:18:58 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:6](0) Loss=2.32534 Rate=138.48 GlobalRate=138.47 Time=Wed Nov  9 06:18:59 2022
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [xla:4](0) Loss=2.28507 Rate=149.48 GlobalRate=149.47 Time=Wed Nov  9 06:19:00 2022
# [xla:2](0) Loss=2.34339 Rate=156.26 GlobalRate=156.25 Time=Wed Nov  9 06:19:01 2022
# [xla:4](20) Loss=0.33390 Rate=402.22 GlobalRate=503.18 Time=Wed Nov  9 06:19:04 2022[xla:3](20) Loss=0.38105 Rate=316.06 GlobalRate=378.59 Time=Wed Nov  9 06:19:04 2022[xla:2](20) Loss=0.36670 Rate=470.60 GlobalRate=586.52 Time=Wed Nov  9 06:19:04 2022[xla:6](20) Loss=0.29053 Rate=328.39 GlobalRate=410.33 Time=Wed Nov  9 06:19:04 2022[xla:0](20) Loss=0.39002 Rate=129.40 GlobalRate=160.74 Time=Wed Nov  9 06:19:04 2022[xla:1](20) Loss=0.29847 Rate=238.21 GlobalRate=241.95 Time=Wed Nov  9 06:19:04 2022[xla:7](20) Loss=0.35615 Rate=247.57 GlobalRate=277.50 Time=Wed Nov  9 06:19:04 2022[xla:5](20) Loss=0.39308 Rate=268.69 GlobalRate=325.06 Time=Wed Nov  9 06:19:04 2022
#
#
#
#
#
#
#
# [xla:2](40) Loss=0.17821 Rate=634.61 GlobalRate=654.03 Time=Wed Nov  9 06:19:08 2022[xla:4](40) Loss=0.11748 Rate=607.86 GlobalRate=597.83 Time=Wed Nov  9 06:19:08 2022
#
# [xla:3](40) Loss=0.22825 Rate=558.45 GlobalRate=492.52 Time=Wed Nov  9 06:19:08 2022
# [xla:6](40) Loss=0.18134 Rate=545.82 GlobalRate=511.66 Time=Wed Nov  9 06:19:08 2022[xla:1](40) Loss=0.17458 Rate=506.98 GlobalRate=353.62 Time=Wed Nov  9 06:19:08 2022
#
# [xla:7](40) Loss=0.18033 Rate=490.37 GlobalRate=385.55 Time=Wed Nov  9 06:19:08 2022[xla:5](40) Loss=0.17910 Rate=496.78 GlobalRate=429.64 Time=Wed Nov  9 06:19:08 2022
#
# [xla:0](40) Loss=0.22881 Rate=406.92 GlobalRate=249.34 Time=Wed Nov  9 06:19:09 2022
# Finished training epoch 1
# [xla:2] Accuracy=96.33%
# [xla:3] Accuracy=96.31%[xla:1] Accuracy=96.31%[xla:4] Accuracy=96.32%
#
#
# [xla:7] Accuracy=96.31%[xla:5] Accuracy=96.31%
#
# [xla:6] Accuracy=96.31%
# [xla:0] Accuracy=96.32%
# [xla:2](0) Loss=0.13660 Rate=104.20 GlobalRate=104.20 Time=Wed Nov  9 06:19:34 2022
# [xla:5](0) Loss=0.17355 Rate=72.39 GlobalRate=72.39 Time=Wed Nov  9 06:19:35 2022[xla:7](0) Loss=0.21495 Rate=76.72 GlobalRate=76.72 Time=Wed Nov  9 06:19:34 2022[xla:4](0) Loss=0.11498 Rate=71.98 GlobalRate=71.98 Time=Wed Nov  9 06:19:35 2022
#
#
# [xla:1](0) Loss=0.16954 Rate=69.42 GlobalRate=69.42 Time=Wed Nov  9 06:19:35 2022[xla:3](0) Loss=0.09402 Rate=68.32 GlobalRate=68.32 Time=Wed Nov  9 06:19:35 2022
#
# [xla:6](0) Loss=0.18631 Rate=57.92 GlobalRate=57.92 Time=Wed Nov  9 06:19:35 2022
# [xla:0](0) Loss=0.15959 Rate=47.13 GlobalRate=47.13 Time=Wed Nov  9 06:19:36 2022
# [xla:1](20) Loss=0.05154 Rate=304.18 GlobalRate=363.20 Time=Wed Nov  9 06:19:40 2022[xla:5](20) Loss=0.17951 Rate=301.07 GlobalRate=362.61 Time=Wed Nov  9 06:19:40 2022[xla:4](20) Loss=0.09715 Rate=301.49 GlobalRate=362.70 Time=Wed Nov  9 06:19:40 2022[xla:3](20) Loss=0.17112 Rate=306.48 GlobalRate=364.44 Time=Wed Nov  9 06:19:40 2022[xla:7](20) Loss=0.16162 Rate=300.06 GlobalRate=364.69 Time=Wed Nov  9 06:19:40 2022[xla:2](20) Loss=0.12526 Rate=283.75 GlobalRate=354.91 Time=Wed Nov  9 06:19:40 2022
#
#
#
#
#
# [xla:6](20) Loss=0.06819 Rate=316.51 GlobalRate=360.99 Time=Wed Nov  9 06:19:40 2022
# [xla:0](20) Loss=0.14682 Rate=320.91 GlobalRate=344.56 Time=Wed Nov  9 06:19:41 2022
# [xla:5](40) Loss=0.07675 Rate=420.36 GlobalRate=418.70 Time=Wed Nov  9 06:19:45 2022[xla:1](40) Loss=0.09461 Rate=421.78 GlobalRate=419.20 Time=Wed Nov  9 06:19:45 2022[xla:2](40) Loss=0.09052 Rate=413.67 GlobalRate=413.53 Time=Wed Nov  9 06:19:45 2022[xla:4](40) Loss=0.04268 Rate=419.73 GlobalRate=418.31 Time=Wed Nov  9 06:19:45 2022
# [xla:7](40) Loss=0.08947 Rate=419.61 GlobalRate=419.92 Time=Wed Nov  9 06:19:45 2022
#
# [xla:3](40) Loss=0.13810 Rate=422.11 GlobalRate=419.70 Time=Wed Nov  9 06:19:45 2022
#
#
# [xla:6](40) Loss=0.08225 Rate=419.41 GlobalRate=413.49 Time=Wed Nov  9 06:19:46 2022
# [xla:0](40) Loss=0.14069 Rate=426.84 GlobalRate=405.33 Time=Wed Nov  9 06:19:46 2022
# Finished training epoch 2
# [xla:7] Accuracy=97.66%[xla:5] Accuracy=97.64%
#
# [xla:3] Accuracy=97.67%[xla:1] Accuracy=97.63%
#
# [xla:4] Accuracy=97.65%
# [xla:6] Accuracy=97.64%
# [xla:2] Accuracy=97.68%
# [xla:0] Accuracy=97.68%
# [xla:5](0) Loss=0.09702 Rate=92.59 GlobalRate=92.59 Time=Wed Nov  9 06:20:11 2022
# [xla:7](0) Loss=0.14549 Rate=74.42 GlobalRate=74.42 Time=Wed Nov  9 06:20:12 2022
# [xla:6](0) Loss=0.12565 Rate=71.97 GlobalRate=71.97 Time=Wed Nov  9 06:20:12 2022
# [xla:4](0) Loss=0.07841 Rate=67.41 GlobalRate=67.41 Time=Wed Nov  9 06:20:12 2022
# [xla:2](0) Loss=0.08536 Rate=61.49 GlobalRate=61.49 Time=Wed Nov  9 06:20:12 2022[xla:1](0) Loss=0.10190 Rate=56.35 GlobalRate=56.35 Time=Wed Nov  9 06:20:12 2022
#
# [xla:3](0) Loss=0.04605 Rate=51.38 GlobalRate=51.38 Time=Wed Nov  9 06:20:12 2022
# [xla:0](0) Loss=0.10644 Rate=49.02 GlobalRate=49.02 Time=Wed Nov  9 06:20:13 2022
# [xla:5](20) Loss=0.13940 Rate=300.80 GlobalRate=373.02 Time=Wed Nov  9 06:20:17 2022[xla:7](20) Loss=0.14062 Rate=311.87 GlobalRate=375.17 Time=Wed Nov  9 06:20:17 2022
#
# [xla:6](20) Loss=0.03514 Rate=310.29 GlobalRate=371.52 Time=Wed Nov  9 06:20:17 2022[xla:4](20) Loss=0.05987 Rate=310.62 GlobalRate=367.53 Time=Wed Nov  9 06:20:17 2022
#
# [xla:1](20) Loss=0.02652 Rate=321.16 GlobalRate=362.50 Time=Wed Nov  9 06:20:17 2022
# [xla:2](20) Loss=0.09047 Rate=311.30 GlobalRate=361.34 Time=Wed Nov  9 06:20:18 2022
# [xla:3](20) Loss=0.13238 Rate=314.31 GlobalRate=348.18 Time=Wed Nov  9 06:20:18 2022
# [xla:0](20) Loss=0.11704 Rate=310.88 GlobalRate=340.92 Time=Wed Nov  9 06:20:18 2022
# [xla:5](40) Loss=0.04586 Rate=413.24 GlobalRate=421.54 Time=Wed Nov  9 06:20:22 2022
# [xla:7](40) Loss=0.05988 Rate=417.48 GlobalRate=422.82 Time=Wed Nov  9 06:20:22 2022
# [xla:1](40) Loss=0.06255 Rate=423.91 GlobalRate=416.04 Time=Wed Nov  9 06:20:23 2022[xla:6](40) Loss=0.05648 Rate=412.38 GlobalRate=417.71 Time=Wed Nov  9 06:20:23 2022[xla:4](40) Loss=0.02536 Rate=414.69 GlobalRate=416.43 Time=Wed Nov  9 06:20:23 2022
#
#
# [xla:2](40) Loss=0.07231 Rate=412.89 GlobalRate=411.11 Time=Wed Nov  9 06:20:23 2022
# [xla:3](40) Loss=0.10083 Rate=412.73 GlobalRate=401.47 Time=Wed Nov  9 06:20:23 2022
# [xla:0](40) Loss=0.11411 Rate=418.66 GlobalRate=400.50 Time=Wed Nov  9 06:20:23 2022
# Finished training epoch 3
# [xla:6] Accuracy=98.04%[xla:7] Accuracy=98.02%
#
# [xla:1] Accuracy=97.99%[xla:3] Accuracy=98.03%[xla:5] Accuracy=98.05%
# [xla:0] Accuracy=98.02%
# [xla:2] Accuracy=98.05%
#
#
# [xla:4] Accuracy=98.03%
# [xla:6](0) Loss=0.09577 Rate=90.75 GlobalRate=90.74 Time=Wed Nov  9 06:20:48 2022
# [xla:1](0) Loss=0.07075 Rate=84.55 GlobalRate=84.55 Time=Wed Nov  9 06:20:48 2022[xla:7](0) Loss=0.11732 Rate=79.12 GlobalRate=79.12 Time=Wed Nov  9 06:20:48 2022
# [xla:5](0) Loss=0.06208 Rate=76.57 GlobalRate=76.57 Time=Wed Nov  9 06:20:49 2022
#
# [xla:2](0) Loss=0.06538 Rate=65.69 GlobalRate=65.69 Time=Wed Nov  9 06:20:49 2022
# [xla:3](0) Loss=0.02979 Rate=62.77 GlobalRate=62.77 Time=Wed Nov  9 06:20:49 2022
# [xla:0](0) Loss=0.08282 Rate=59.06 GlobalRate=59.06 Time=Wed Nov  9 06:20:49 2022
# [xla:4](0) Loss=0.06123 Rate=60.02 GlobalRate=60.02 Time=Wed Nov  9 06:20:49 2022
# [xla:6](20) Loss=0.02210 Rate=315.96 GlobalRate=389.41 Time=Wed Nov  9 06:20:54 2022
# [xla:7](20) Loss=0.12415 Rate=314.01 GlobalRate=380.87 Time=Wed Nov  9 06:20:54 2022
# [xla:1](20) Loss=0.01770 Rate=304.71 GlobalRate=374.16 Time=Wed Nov  9 06:20:54 2022
# [xla:5](20) Loss=0.11635 Rate=298.42 GlobalRate=362.88 Time=Wed Nov  9 06:20:54 2022[xla:3](20) Loss=0.11496 Rate=314.44 GlobalRate=365.82 Time=Wed Nov  9 06:20:54 2022
#
# [xla:2](20) Loss=0.07815 Rate=300.53 GlobalRate=356.06 Time=Wed Nov  9 06:20:54 2022[xla:0](20) Loss=0.10371 Rate=309.59 GlobalRate=356.56 Time=Wed Nov  9 06:20:55 2022
#
# [xla:4](20) Loss=0.04506 Rate=307.95 GlobalRate=356.40 Time=Wed Nov  9 06:20:55 2022
# [xla:6](40) Loss=0.04501 Rate=405.89 GlobalRate=423.29 Time=Wed Nov  9 06:20:59 2022
# [xla:1](40) Loss=0.04601 Rate=414.18 GlobalRate=421.90 Time=Wed Nov  9 06:20:59 2022[xla:7](40) Loss=0.04362 Rate=405.03 GlobalRate=418.02 Time=Wed Nov  9 06:20:59 2022
#
# [xla:3](40) Loss=0.07713 Rate=413.81 GlobalRate=413.86 Time=Wed Nov  9 06:21:00 2022[xla:5](40) Loss=0.03097 Rate=406.48 GlobalRate=411.37 Time=Wed Nov  9 06:21:00 2022
#
# [xla:2](40) Loss=0.06144 Rate=399.15 GlobalRate=401.96 Time=Wed Nov  9 06:21:00 2022[xla:4](40) Loss=0.01852 Rate=407.27 GlobalRate=405.28 Time=Wed Nov  9 06:21:00 2022
# [xla:0](40) Loss=0.10238 Rate=400.93 GlobalRate=401.17 Time=Wed Nov  9 06:21:00 2022
#
# Finished training epoch 4
# [xla:7] Accuracy=98.38%[xla:5] Accuracy=98.38%
#
# [xla:2] Accuracy=98.35%
# [xla:3] Accuracy=98.37%
# [xla:1] Accuracy=98.35%
# [xla:4] Accuracy=98.34%[xla:6] Accuracy=98.37%
#
# [xla:0] Accuracy=98.33%
# [xla:7](0) Loss=0.09815 Rate=74.77 GlobalRate=74.77 Time=Wed Nov  9 06:21:26 2022
# [xla:3](0) Loss=0.02107 Rate=72.56 GlobalRate=72.55 Time=Wed Nov  9 06:21:26 2022
# [xla:5](0) Loss=0.04418 Rate=64.18 GlobalRate=64.18 Time=Wed Nov  9 06:21:26 2022
# [xla:2](0) Loss=0.05210 Rate=57.41 GlobalRate=57.41 Time=Wed Nov  9 06:21:27 2022[xla:1](0) Loss=0.06086 Rate=62.40 GlobalRate=62.40 Time=Wed Nov  9 06:21:27 2022
#
# [xla:4](0) Loss=0.04900 Rate=55.39 GlobalRate=55.39 Time=Wed Nov  9 06:21:27 2022
# [xla:6](0) Loss=0.07338 Rate=52.92 GlobalRate=52.92 Time=Wed Nov  9 06:21:27 2022[xla:0](0) Loss=0.06513 Rate=54.37 GlobalRate=54.37 Time=Wed Nov  9 06:21:27 2022
#
# [xla:7](20) Loss=0.10759 Rate=299.01 GlobalRate=362.27 Time=Wed Nov  9 06:21:32 2022
# [xla:3](20) Loss=0.10352 Rate=295.34 GlobalRate=356.89 Time=Wed Nov  9 06:21:32 2022
# [xla:5](20) Loss=0.09952 Rate=287.26 GlobalRate=341.72 Time=Wed Nov  9 06:21:32 2022[xla:2](20) Loss=0.07109 Rate=300.11 GlobalRate=345.87 Time=Wed Nov  9 06:21:32 2022
#
# [xla:4](20) Loss=0.03756 Rate=299.46 GlobalRate=342.43 Time=Wed Nov  9 06:21:32 2022
# [xla:1](20) Loss=0.01393 Rate=285.68 GlobalRate=338.42 Time=Wed Nov  9 06:21:33 2022[xla:6](20) Loss=0.01459 Rate=300.29 GlobalRate=339.32 Time=Wed Nov  9 06:21:33 2022
#
# [xla:0](20) Loss=0.09266 Rate=291.26 GlobalRate=333.77 Time=Wed Nov  9 06:21:33 2022
# [xla:3](40) Loss=0.06276 Rate=395.01 GlobalRate=401.24 Time=Wed Nov  9 06:21:38 2022[xla:7](40) Loss=0.03425 Rate=385.40 GlobalRate=397.62 Time=Wed Nov  9 06:21:38 2022[xla:2](40) Loss=0.05702 Rate=403.12 GlobalRate=397.64 Time=Wed Nov  9 06:21:38 2022
#
#
# [xla:5](40) Loss=0.02148 Rate=389.56 GlobalRate=389.93 Time=Wed Nov  9 06:21:38 2022[xla:4](40) Loss=0.01368 Rate=405.55 GlobalRate=396.83 Time=Wed Nov  9 06:21:38 2022
#
# [xla:1](40) Loss=0.03577 Rate=390.72 GlobalRate=388.77 Time=Wed Nov  9 06:21:38 2022
# [xla:6](40) Loss=0.03727 Rate=389.68 GlobalRate=385.32 Time=Wed Nov  9 06:21:38 2022
# [xla:0](40) Loss=0.09754 Rate=384.03 GlobalRate=380.43 Time=Wed Nov  9 06:21:39 2022
# Finished training epoch 5
# [xla:5] Accuracy=98.52%
# [xla:1] Accuracy=98.51%
# [xla:2] Accuracy=98.55%
# [xla:7] Accuracy=98.53%
# [xla:0] Accuracy=98.54%[xla:3] Accuracy=98.55%
#
# [xla:6] Accuracy=98.53%
# [xla:4] Accuracy=98.54%
# [xla:5](0) Loss=0.03461 Rate=77.46 GlobalRate=77.46 Time=Wed Nov  9 06:22:05 2022
# [xla:2](0) Loss=0.04471 Rate=71.62 GlobalRate=71.62 Time=Wed Nov  9 06:22:05 2022
# [xla:1](0) Loss=0.05428 Rate=67.90 GlobalRate=67.90 Time=Wed Nov  9 06:22:05 2022[xla:3](0) Loss=0.01554 Rate=70.97 GlobalRate=70.97 Time=Wed Nov  9 06:22:05 2022[xla:7](0) Loss=0.08832 Rate=71.95 GlobalRate=71.95 Time=Wed Nov  9 06:22:05 2022
#
#
# [xla:0](0) Loss=0.05450 Rate=59.72 GlobalRate=59.72 Time=Wed Nov  9 06:22:05 2022
# [xla:6](0) Loss=0.05827 Rate=54.69 GlobalRate=54.69 Time=Wed Nov  9 06:22:06 2022
# [xla:4](0) Loss=0.04088 Rate=53.19 GlobalRate=53.19 Time=Wed Nov  9 06:22:06 2022
# [xla:5](20) Loss=0.08378 Rate=296.04 GlobalRate=360.93 Time=Wed Nov  9 06:22:10 2022[xla:7](20) Loss=0.09521 Rate=308.33 GlobalRate=369.56 Time=Wed Nov  9 06:22:10 2022
#
# [xla:3](20) Loss=0.09458 Rate=304.85 GlobalRate=365.25 Time=Wed Nov  9 06:22:10 2022[xla:2](20) Loss=0.06722 Rate=298.54 GlobalRate=359.44 Time=Wed Nov  9 06:22:11 2022[xla:1](20) Loss=0.01240 Rate=301.12 GlobalRate=358.80 Time=Wed Nov  9 06:22:11 2022
#
#
# [xla:6](20) Loss=0.01081 Rate=309.28 GlobalRate=349.78 Time=Wed Nov  9 06:22:11 2022[xla:0](20) Loss=0.08370 Rate=294.90 GlobalRate=344.13 Time=Wed Nov  9 06:22:11 2022
#
# [xla:4](20) Loss=0.03248 Rate=299.73 GlobalRate=339.28 Time=Wed Nov  9 06:22:11 2022
# [xla:1](40) Loss=0.02866 Rate=394.26 GlobalRate=400.57 Time=Wed Nov  9 06:22:16 2022[xla:2](40) Loss=0.05400 Rate=393.26 GlobalRate=401.00 Time=Wed Nov  9 06:22:16 2022[xla:7](40) Loss=0.02791 Rate=392.37 GlobalRate=404.23 Time=Wed Nov  9 06:22:16 2022[xla:5](40) Loss=0.01626 Rate=384.77 GlobalRate=397.15 Time=Wed Nov  9 06:22:16 2022[xla:0](40) Loss=0.09194 Rate=415.87 GlobalRate=404.72 Time=Wed Nov  9 06:22:16 2022[xla:3](40) Loss=0.05268 Rate=394.55 GlobalRate=403.88 Time=Wed Nov  9 06:22:16 2022
#
#
#
#
#
# [xla:6](40) Loss=0.03225 Rate=388.13 GlobalRate=388.92 Time=Wed Nov  9 06:22:17 2022
# [xla:4](40) Loss=0.01070 Rate=387.25 GlobalRate=383.97 Time=Wed Nov  9 06:22:17 2022
# Finished training epoch 6
# [xla:5] Accuracy=98.62%
# [xla:4] Accuracy=98.66%
# [xla:7] Accuracy=98.63%
# [xla:1] Accuracy=98.63%
# [xla:2] Accuracy=98.64%
# [xla:6] Accuracy=98.65%[xla:0] Accuracy=98.63%
#
# [xla:3] Accuracy=98.63%
# [xla:5](0) Loss=0.02839 Rate=91.12 GlobalRate=91.12 Time=Wed Nov  9 06:22:41 2022
# [xla:4](0) Loss=0.03350 Rate=78.32 GlobalRate=78.32 Time=Wed Nov  9 06:22:42 2022
# [xla:7](0) Loss=0.08259 Rate=73.29 GlobalRate=73.29 Time=Wed Nov  9 06:22:42 2022
# [xla:1](0) Loss=0.04978 Rate=81.04 GlobalRate=81.04 Time=Wed Nov  9 06:22:42 2022
# [xla:2](0) Loss=0.03998 Rate=66.17 GlobalRate=66.17 Time=Wed Nov  9 06:22:42 2022
# [xla:6](0) Loss=0.04735 Rate=57.89 GlobalRate=57.89 Time=Wed Nov  9 06:22:42 2022
# [xla:0](0) Loss=0.04834 Rate=56.13 GlobalRate=56.13 Time=Wed Nov  9 06:22:43 2022
# [xla:3](0) Loss=0.01182 Rate=51.44 GlobalRate=51.44 Time=Wed Nov  9 06:22:43 2022
# [xla:1](20) Loss=0.01078 Rate=326.40 GlobalRate=395.04 Time=Wed Nov  9 06:22:47 2022[xla:7](20) Loss=0.08452 Rate=320.72 GlobalRate=383.04 Time=Wed Nov  9 06:22:47 2022[xla:5](20) Loss=0.07127 Rate=300.97 GlobalRate=372.74 Time=Wed Nov  9 06:22:47 2022
#
#
# [xla:4](20) Loss=0.02855 Rate=309.82 GlobalRate=375.96 Time=Wed Nov  9 06:22:47 2022
# [xla:2](20) Loss=0.06130 Rate=318.84 GlobalRate=373.96 Time=Wed Nov  9 06:22:47 2022
# [xla:3](20) Loss=0.08684 Rate=333.81 GlobalRate=363.64 Time=Wed Nov  9 06:22:48 2022[xla:0](20) Loss=0.07502 Rate=321.58 GlobalRate=362.49 Time=Wed Nov  9 06:22:48 2022[xla:6](20) Loss=0.00900 Rate=314.72 GlobalRate=359.39 Time=Wed Nov  9 06:22:48 2022
#
#
# [xla:1](40) Loss=0.02390 Rate=421.54 GlobalRate=434.33 Time=Wed Nov  9 06:22:52 2022[xla:5](40) Loss=0.01241 Rate=411.54 GlobalRate=420.28 Time=Wed Nov  9 06:22:52 2022[xla:7](40) Loss=0.02300 Rate=419.35 GlobalRate=426.85 Time=Wed Nov  9 06:22:52 2022[xla:4](40) Loss=0.00834 Rate=418.95 GlobalRate=424.73 Time=Wed Nov  9 06:22:52 2022
#
#
#
# [xla:2](40) Loss=0.05069 Rate=415.08 GlobalRate=418.84 Time=Wed Nov  9 06:22:53 2022
# [xla:0](40) Loss=0.08613 Rate=426.41 GlobalRate=417.38 Time=Wed Nov  9 06:22:53 2022
# [xla:6](40) Loss=0.02883 Rate=414.20 GlobalRate=409.78 Time=Wed Nov  9 06:22:53 2022[xla:3](40) Loss=0.04351 Rate=418.17 GlobalRate=410.38 Time=Wed Nov  9 06:22:53 2022
#
# Finished training epoch 7
# [xla:6] Accuracy=98.69%[xla:2] Accuracy=98.71%
# [xla:1] Accuracy=98.74%
#
# [xla:7] Accuracy=98.70%[xla:4] Accuracy=98.72%[xla:3] Accuracy=98.72%
#
#
# [xla:5] Accuracy=98.69%
# [xla:0] Accuracy=98.72%
# [xla:2](0) Loss=0.03586 Rate=85.55 GlobalRate=85.55 Time=Wed Nov  9 06:23:18 2022
# [xla:6](0) Loss=0.03892 Rate=81.85 GlobalRate=81.85 Time=Wed Nov  9 06:23:18 2022
# [xla:3](0) Loss=0.00968 Rate=74.53 GlobalRate=74.53 Time=Wed Nov  9 06:23:18 2022
# [xla:1](0) Loss=0.04623 Rate=65.59 GlobalRate=65.59 Time=Wed Nov  9 06:23:18 2022[xla:4](0) Loss=0.02734 Rate=65.82 GlobalRate=65.82 Time=Wed Nov  9 06:23:18 2022[xla:7](0) Loss=0.07555 Rate=65.93 GlobalRate=65.93 Time=Wed Nov  9 06:23:18 2022[xla:5](0) Loss=0.02375 Rate=68.76 GlobalRate=68.76 Time=Wed Nov  9 06:23:18 2022
#
#
#
# [xla:0](0) Loss=0.04649 Rate=52.39 GlobalRate=52.39 Time=Wed Nov  9 06:23:19 2022
# [xla:6](20) Loss=0.00758 Rate=308.66 GlobalRate=376.96 Time=Wed Nov  9 06:23:24 2022[xla:2](20) Loss=0.05696 Rate=308.36 GlobalRate=378.63 Time=Wed Nov  9 06:23:24 2022[xla:3](20) Loss=0.08186 Rate=318.75 GlobalRate=382.17 Time=Wed Nov  9 06:23:24 2022
#
# [xla:7](20) Loss=0.07632 Rate=322.55 GlobalRate=377.13 Time=Wed Nov  9 06:23:24 2022
# [xla:1](20) Loss=0.01005 Rate=317.96 GlobalRate=372.46 Time=Wed Nov  9 06:23:24 2022
# [xla:4](20) Loss=0.02579 Rate=315.21 GlobalRate=370.16 Time=Wed Nov  9 06:23:24 2022
#
# [xla:5](20) Loss=0.06029 Rate=312.36 GlobalRate=370.57 Time=Wed Nov  9 06:23:24 2022
# [xla:0](20) Loss=0.06745 Rate=314.70 GlobalRate=350.36 Time=Wed Nov  9 06:23:24 2022
# [xla:6](40) Loss=0.02666 Rate=418.33 GlobalRate=425.29 Time=Wed Nov  9 06:23:29 2022[xla:2](40) Loss=0.04931 Rate=418.22 GlobalRate=426.38 Time=Wed Nov  9 06:23:29 2022[xla:4](40) Loss=0.00696 Rate=433.51 GlobalRate=428.13 Time=Wed Nov  9 06:23:29 2022
#
#
# [xla:7](40) Loss=0.01932 Rate=423.29 GlobalRate=425.03 Time=Wed Nov  9 06:23:29 2022[xla:3](40) Loss=0.03627 Rate=414.68 GlobalRate=423.84 Time=Wed Nov  9 06:23:29 2022
#
# [xla:1](40) Loss=0.02040 Rate=417.21 GlobalRate=419.41 Time=Wed Nov  9 06:23:29 2022
# [xla:5](40) Loss=0.01040 Rate=402.20 GlobalRate=410.20 Time=Wed Nov  9 06:23:29 2022
# [xla:0](40) Loss=0.08127 Rate=420.61 GlobalRate=407.33 Time=Wed Nov  9 06:23:30 2022
# Finished training epoch 8
# [xla:6] Accuracy=98.83%
# [xla:3] Accuracy=98.84%
# [xla:1] Accuracy=98.82%
# [xla:0] Accuracy=98.84%
# [xla:5] Accuracy=98.86%[xla:2] Accuracy=98.84%
#
# [xla:4] Accuracy=98.83%[xla:7] Accuracy=98.85%
#
# [xla:6](0) Loss=0.03305 Rate=86.43 GlobalRate=86.43 Time=Wed Nov  9 06:23:54 2022
# [xla:3](0) Loss=0.00802 Rate=87.35 GlobalRate=87.35 Time=Wed Nov  9 06:23:54 2022
# [xla:0](0) Loss=0.04225 Rate=73.87 GlobalRate=73.87 Time=Wed Nov  9 06:23:55 2022
# [xla:1](0) Loss=0.04254 Rate=73.65 GlobalRate=73.65 Time=Wed Nov  9 06:23:55 2022
# [xla:5](0) Loss=0.02099 Rate=65.29 GlobalRate=65.29 Time=Wed Nov  9 06:23:55 2022
# [xla:2](0) Loss=0.03407 Rate=61.42 GlobalRate=61.42 Time=Wed Nov  9 06:23:55 2022
# [xla:7](0) Loss=0.06954 Rate=57.74 GlobalRate=57.74 Time=Wed Nov  9 06:23:55 2022
# [xla:4](0) Loss=0.02312 Rate=56.35 GlobalRate=56.35 Time=Wed Nov  9 06:23:55 2022
# [xla:3](20) Loss=0.08044 Rate=297.66 GlobalRate=367.62 Time=Wed Nov  9 06:24:00 2022[xla:6](20) Loss=0.00713 Rate=292.28 GlobalRate=361.23 Time=Wed Nov  9 06:24:00 2022
#
# [xla:0](20) Loss=0.06211 Rate=310.23 GlobalRate=373.06 Time=Wed Nov  9 06:24:00 2022[xla:1](20) Loss=0.01042 Rate=309.98 GlobalRate=372.63 Time=Wed Nov  9 06:24:00 2022
#
# [xla:5](20) Loss=0.05184 Rate=315.69 GlobalRate=370.01 Time=Wed Nov  9 06:24:00 2022
# [xla:2](20) Loss=0.05253 Rate=303.84 GlobalRate=354.43 Time=Wed Nov  9 06:24:00 2022
# [xla:4](20) Loss=0.02406 Rate=312.19 GlobalRate=354.88 Time=Wed Nov  9 06:24:01 2022
# [xla:7](20) Loss=0.07022 Rate=292.84 GlobalRate=339.78 Time=Wed Nov  9 06:24:01 2022
# [xla:5](40) Loss=0.00881 Rate=422.97 GlobalRate=421.80 Time=Wed Nov  9 06:24:05 2022[xla:3](40) Loss=0.03037 Rate=401.93 GlobalRate=411.87 Time=Wed Nov  9 06:24:05 2022[xla:6](40) Loss=0.02426 Rate=400.00 GlobalRate=407.86 Time=Wed Nov  9 06:24:05 2022[xla:1](40) Loss=0.01877 Rate=413.76 GlobalRate=419.36 Time=Wed Nov  9 06:24:05 2022[xla:0](40) Loss=0.07746 Rate=410.78 GlobalRate=417.74 Time=Wed Nov  9 06:24:05 2022
#
#
#
#
# [xla:2](40) Loss=0.04657 Rate=414.83 GlobalRate=409.33 Time=Wed Nov  9 06:24:06 2022
# [xla:4](40) Loss=0.00590 Rate=413.50 GlobalRate=406.94 Time=Wed Nov  9 06:24:06 2022
# [xla:7](40) Loss=0.01703 Rate=404.57 GlobalRate=395.93 Time=Wed Nov  9 06:24:06 2022
# Finished training epoch 9
# [xla:2] Accuracy=98.86%
# [xla:3] Accuracy=98.87%
# [xla:1] Accuracy=98.86%
# [xla:6] Accuracy=98.88%
# [xla:7] Accuracy=98.88%
# [xla:5] Accuracy=98.89%
# [xla:4] Accuracy=98.87%[xla:0] Accuracy=98.87%
#
# [xla:2](0) Loss=0.03119 Rate=94.02 GlobalRate=94.02 Time=Wed Nov  9 06:24:31 2022
# [xla:3](0) Loss=0.00696 Rate=78.35 GlobalRate=78.35 Time=Wed Nov  9 06:24:31 2022
# [xla:6](0) Loss=0.02907 Rate=76.00 GlobalRate=76.00 Time=Wed Nov  9 06:24:31 2022
# [xla:1](0) Loss=0.03937 Rate=69.25 GlobalRate=69.25 Time=Wed Nov  9 06:24:31 2022
# [xla:7](0) Loss=0.06753 Rate=64.67 GlobalRate=64.67 Time=Wed Nov  9 06:24:31 2022
# [xla:5](0) Loss=0.01904 Rate=60.29 GlobalRate=60.29 Time=Wed Nov  9 06:24:32 2022
# [xla:4](0) Loss=0.01980 Rate=54.64 GlobalRate=54.64 Time=Wed Nov  9 06:24:32 2022
# [xla:0](0) Loss=0.03708 Rate=47.38 GlobalRate=47.38 Time=Wed Nov  9 06:24:32 2022
# [xla:1](20) Loss=0.00997 Rate=308.92 GlobalRate=367.70 Time=Wed Nov  9 06:24:37 2022[xla:7](20) Loss=0.06498 Rate=317.06 GlobalRate=370.54 Time=Wed Nov  9 06:24:37 2022[xla:6](20) Loss=0.00649 Rate=304.13 GlobalRate=368.43 Time=Wed Nov  9 06:24:37 2022[xla:2](20) Loss=0.04872 Rate=290.69 GlobalRate=361.75 Time=Wed Nov  9 06:24:37 2022[xla:3](20) Loss=0.07750 Rate=294.18 GlobalRate=359.48 Time=Wed Nov  9 06:24:37 2022[xla:4](20) Loss=0.02224 Rate=344.91 GlobalRate=378.74 Time=Wed Nov  9 06:24:37 2022
#
#
#
#
#
# [xla:5](20) Loss=0.04686 Rate=309.21 GlobalRate=357.88 Time=Wed Nov  9 06:24:37 2022
# [xla:0](20) Loss=0.05790 Rate=311.93 GlobalRate=338.36 Time=Wed Nov  9 06:24:38 2022
# [xla:2](40) Loss=0.04412 Rate=406.61 GlobalRate=412.54 Time=Wed Nov  9 06:24:42 2022[xla:4](40) Loss=0.00509 Rate=429.32 GlobalRate=424.28 Time=Wed Nov  9 06:24:42 2022[xla:6](40) Loss=0.02230 Rate=411.80 GlobalRate=416.85 Time=Wed Nov  9 06:24:42 2022[xla:7](40) Loss=0.01527 Rate=416.48 GlobalRate=417.93 Time=Wed Nov  9 06:24:42 2022[xla:1](40) Loss=0.01710 Rate=413.56 GlobalRate=416.28 Time=Wed Nov  9 06:24:42 2022[xla:3](40) Loss=0.02684 Rate=407.85 GlobalRate=410.94 Time=Wed Nov  9 06:24:42 2022
#
#
#
#
#
# [xla:5](40) Loss=0.00743 Rate=424.57 GlobalRate=415.99 Time=Wed Nov  9 06:24:42 2022
# [xla:0](40) Loss=0.07393 Rate=426.58 GlobalRate=402.66 Time=Wed Nov  9 06:24:43 2022
# Finished training epoch 10
# [xla:1] Accuracy=98.91%[xla:6] Accuracy=98.90%[xla:7] Accuracy=98.90%
#
#
# [xla:2] Accuracy=98.91%[xla:4] Accuracy=98.91%
#
# [xla:5] Accuracy=98.92%
# [xla:3] Accuracy=98.90%
# [xla:0] Accuracy=98.90%

# %% [markdown]
# ## Visualize Predictions

# %%
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread(RESULT_IMG_PATH, cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=792x648 at 0x7F0C6492BD10>
